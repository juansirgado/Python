# %%
import rsa
 
publicKey, privateKey = rsa.newkeys(512)
print("Private Key: ", privateKey)
print("Public Key: ", publicKey)

pwd = "test@#$%123"

epw = rsa.encrypt(pwd.encode(),publicKey)

print("Original string: ", pwd)
print("Encrypted string: ", epw)

dpw = rsa.decrypt(epw, privateKey).decode()

print("Decrypted string: ", dpw)
# Out:
# Private Key:  PrivateKey(7596953567028568951099014947144307192545861079579929250531247388633836772046499809858635242153256355618928438118401751848631991906697976212642020873392629, 65537, 1527806399643507313051940384872087046977347895522582167661043999301066093815252727813258011909811777282755394906094389806986840865108734209355747793055233, 4947090246661576371242603358285724765518468212184204069571206102744139949727107233, 1535640788472615482327138398247831261608244569545155673629462037526144213)
# Public Key:  PublicKey(7596953567028568951099014947144307192545861079579929250531247388633836772046499809858635242153256355618928438118401751848631991906697976212642020873392629, 65537)
# Original string:  test@#$%123
# Encrypted string:  b'S\x81Z\xbe\x9f\xa6\x94\\\x8f\r&\x97\x85\xa9\x08\x94\xc5-\x0c\x03\xa64\xd4\\\xd8\x07\xe6\x8b\xa0V\xd9V\x99\x9cwo\x98\x84\xcc[\x898mi\x07K\xc4\xa3\xe5D\xd8\xc8\xba\x8f\x9d$S\xed\xd0\xfa!\x00\xda\xf1'
# Decrypted string:  test@#$%123
