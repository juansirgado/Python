# %%
#----------------------------------------------------------#
#            Program: Draw Cubes 2025/07/17                #
#               All rights reserved 2021                   #
#----------------------------------------------------------#
#     From: Ekobots Innovation Ltda - www.ekobots.com      #
#       by: Juan Sirgado y Antico - www.jsya.com.br        #
#----------------------------------------------------------#
# Description:                                             # 
# Draw color cubes using turtle object                     #
#----------------------------------------------------------#
import turtle
import time

# %%
#----------------------------------------------------------#
t = turtle.Turtle()
t.speed(0)
x = 100
c = ['Red','Green','Blue','Yellow','Orange','Pink','Purple','Brown','White','Black',]
#----------------------------------------------------------#

screen = turtle.Screen()  # Grab/create a resource e.g. a window
screen.clear()
screen.title("Draw my Cubes")
screen.screensize(680,680)

for i in range(72):
    t.color(c[i%8])
    t.circle(200)
    t.left(5)

turtle.done()
time.sleep(10)
#----------------------------------------------------------#

# %%
screen.bye()
#----------------------------------------------------------#
# That is all folks!                                       #
#----------------------------------------------------------#
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 screen.bye()
#       2 #----------------------------------------------------------#
#       3 # That is all folks!                                       #
#       4 #----------------------------------------------------------#
#
# File c:\Program Files\Python313\Lib\turtle.py:3798, in _Screen.bye(self)
#    3792 def bye(self):
#    3793     """Shut the turtlegraphics window.
#    3794
#    3795     Example (for a TurtleScreen instance named screen):
#    3796     >>> screen.bye()
#    3797     """
# -> 3798     self._destroy()
#
# File c:\Program Files\Python313\Lib\turtle.py:3790, in _Screen._destroy(self)
#    3788     _Screen._canvas = None
#    3789 TurtleScreen._RUNNING = False
# -> 3790 root.destroy()
#
# File c:\Program Files\Python313\Lib\tkinter\__init__.py:2503, in Tk.destroy(self)
#    2500 """Destroy this and all descendants widgets. This will
#    2501 end the application of this Tcl interpreter."""
#    2502 for c in list(self.children.values()): c.destroy()
# -> 2503 self.tk.call('destroy', self._w)
#    2504 Misc.destroy(self)
#    2505 global _default_root
#
# TclError: can't invoke "destroy" command: application has been destroyed
