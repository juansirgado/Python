# %%
from cryptography.fernet import Fernet

pwd = "estab09#"
 
key = Fernet.generate_key()
fnk = Fernet(key)
print("Fernet key: ", fnk)

epw = fnk.encrypt(pwd.encode())
 
print("Original string: ", pwd)
print("Encrypted string: ", epw)

dpw = fnk.decrypt(epw).decode()
 
print("Decrypted string: ", dpw)
# Out:
# Fernet key:  <cryptography.fernet.Fernet object at 0x000001F33AA79410>
# Original string:  estab09#
# Encrypted string:  b'gAAAAABkSeOLDpMh1b-Kk7FY_qo-wBqV9bc17MkS2y5MesRsGJHawkxjU7YKub61HACFMnbB_teSimhnK6vZi23gGSkVZWn8wQ=='
# Decrypted string:  estab09#
